# %%
print("welcome to our first github code")
# Out:
# welcome to our first github code

# %%
sum = 5 + 8
print(sum)
# Out:
# 13

# %%
print("i am testing this new line in my code and testing the pull command")
# Out:
# i am testing this new line in my code and testing the pull command
